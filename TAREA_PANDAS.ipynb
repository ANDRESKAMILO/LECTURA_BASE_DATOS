# %% [markdown]
# <a href="https://colab.research.google.com/github/ANDRESKAMILO/LECTURA_BASE_DATOS/blob/main/TAREA_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *ANDRES CAMILO BUITRAGO GÓMEZ - INGENIERO ELECTRÓNICO*

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # LECTRURA BASE DE DATOS
#
# * Leer los archivos que estén en el siguiente repositorio de Harry [link](https://github.com/HarryVargas96/UdeCataluna).
#
# * Crear una cuenta de GitHub.
#
# * Crear un Repositorio Público y suban 3 archivos, archivos propuesta.
#
# * Leer archivos de su repositorio creado enb el numeral 3. usando en google colab y pandas.
#
# * Compartir el link del repositorio en el foro.

# %% [markdown]
# ## 1. Base De Datos, Respositorio Profesor Harry Vargas

# %% [markdown]
# ### 1.1 Londonair

# %%
Lond = pd.read_csv("https://raw.githubusercontent.com/HarryVargas96/UdeCataluna/main/Londonair.csv")
Lond
# Out:
#       Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 0      CT2   PM2.5  01/01/2018 00:00   14.0  ug m-3                       R
# 1      CT2   PM2.5  01/01/2018 00:15   14.0  ug m-3                       R
# 2      CT2   PM2.5  01/01/2018 00:30   14.0  ug m-3                       R
# 3      CT2   PM2.5  01/01/2018 00:45   14.0  ug m-3                       R
# 4      CT2   PM2.5  01/01/2018 01:00    8.0  ug m-3                       R
# ...    ...     ...               ...    ...     ...                     ...
# 35035  CT2   PM2.5  31/12/2018 22:45   10.0  ug m-3                       R
# 35036  CT2   PM2.5  31/12/2018 23:00   10.0  ug m-3                       R
# 35037  CT2   PM2.5  31/12/2018 23:15   10.0  ug m-3                       R
# 35038  CT2   PM2.5  31/12/2018 23:30   10.0  ug m-3                       R
# 35039  CT2   PM2.5  31/12/2018 23:45   10.0  ug m-3                       R
#
# [35040 rows x 6 columns]

# %% [markdown]
# ### 1.2 winequality-white

# %%
wineq = pd.read_csv("https://raw.githubusercontent.com/HarryVargas96/UdeCataluna/main/winequality-white.csv")
wineq
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# ...                                                 ...
# 4893  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4894  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4895  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4896  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4897  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...
#
# [4898 rows x 1 columns]

# %% [markdown]
# ### 1.3 Countries Of The World

# %%
C_world = pd.read_csv("https://raw.githubusercontent.com/HarryVargas96/UdeCataluna/main/countries%20of%20the%20world.csv")
C_world
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %% [markdown]
# ### 2. DATASET_PROPUESTAS_TAREA1

# %% [markdown]
# ### 2.1 DATASET CERAMICAS
#
# * Este dataset puede ser encontrado en UCI Machine
# Learning, comprende 19 variables y 88 observaciones o registros. Cada registro representa un fragmento típico en cuatro épocas culturales para investigar las materias primas y la tecnología de cocción el cual es el objeto de estudio principal. [Dataset](https://archive.ics.uci.edu/ml/datasets/Chemical+Composition+of+Ceramic+Samples)

# %%
Ceramic = pd.read_csv("https://raw.githubusercontent.com/ANDRESKAMILO/LECTURA_BASE_DATOS/main/Chemical%20Composion%20of%20Ceramic.csv")
Ceramic
# Out:
#    Ceramic Name   Part  Na2O   MgO  Al2O3   SiO2   K2O    CaO  TiO2  Fe2O3  \
# 0       FLQ-1-b   Body  0.62  0.38  19.61  71.99  4.84   0.31  0.07   1.18
# 1       FLQ-2-b   Body  0.57  0.47  21.19  70.09  4.98   0.49  0.09   1.12
# 2       FLQ-3-b   Body  0.49  0.19  18.60  74.70  3.47   0.43  0.06   1.07
# 3       FLQ-4-b   Body  0.89  0.30  18.01  74.19  4.01   0.27  0.09   1.23
# 4       FLQ-5-b   Body  0.03  0.36  18.41  73.99  4.33   0.65  0.05   1.19
# ..          ...    ...   ...   ...    ...    ...   ...    ...   ...    ...
# 83     DY-M-3-g  Glaze  0.34  0.55  12.37  70.70  5.33   8.06  0.06   1.61
# 84    DY-QC-1-g  Glaze  0.72  0.34  12.20  72.19  6.19   6.06  0.04   1.27
# 85    DY-QC-2-g  Glaze  0.23  0.24  12.99  71.81  5.25   7.15  0.05   1.29
# 86    DY-QC-3-g  Glaze  0.14  0.46  12.62  69.16  4.34  11.03  0.05   1.20
# 87    DY-QC-4-g  Glaze  0.14  0.63  14.25  71.55  4.87   6.43  0.08   1.05
#
#      MnO  CuO  ZnO  PbO2  Rb2O  SrO  Y2O3  ZrO2  P2O5
# ...

# %% [markdown]
# ### 2.2 DATASET PASSWORD
#
# * Este conjunto de datos contiene 10000 filas y 9 columnas. Si su contraseña está en esta lista de 10,000 contraseñas más comunes, necesita una nueva contraseña. Cada fila corresponde a una contraseña y sus posibles combinaciones. El dataset está constituido por 8 variables cuantitativas continuas y 1 variable cualitativa ordinal.[Dataset](https://www.kaggle.com/datasets/shivamb/10000-most-common-passwords)

# %%
Password = pd.read_csv("https://raw.githubusercontent.com/ANDRESKAMILO/LECTURA_BASE_DATOS/main/common_passwords.csv")
Password
# Out:
#        password  length  num_chars  num_digits  num_upper  num_lower  \
# 0        123456       6          0           6          0          0
# 1      password       8          8           0          0          8
# 2      12345678       8          0           8          0          0
# 3        qwerty       6          6           0          0          6
# 4     123456789       9          0           9          0          0
# ...         ...     ...        ...         ...        ...        ...
# 9995       caca       4          4           0          0          4
# 9996     c2h5oh       6          4           2          0          4
# 9997   bubbles1       8          7           1          0          7
# 9998      brook       5          5           0          0          5
# 9999      brady       5          5           0          0          5
#
#       num_special  num_vowels  num_syllables
# 0               0           0              1
# 1               0           2              2
# ...

# %% [markdown]
# ### 2.3 DATASET FIFA
#
# * Este conjunto de datos proporciona una descripción completa de todos los partidos de fútbol internacionales jugados desde los años 90. Además de eso, la fuerza de cada equipo se proporciona mediante la incorporación de clasificaciones reales de FIFA, así como las fortalezas de los jugadores basadas en el videojuego EA Sport FIFA. [Dataset](https://www.kaggle.com/datasets/brenda89/fifa-world-cup-2022)

# %%
PULPO = pd.read_csv("https://raw.githubusercontent.com/ANDRESKAMILO/LECTURA_BASE_DATOS/main/international_matches.csv")
PULPO
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...
